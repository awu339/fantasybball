# %%
import numpy as np
import pandas as pd 
from IPython.display import display
import os 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
file_path = ('fantasybball.xlsx', "Week 5)
df = pd.read_excel(file_path, engine='openpyxl')

df.rename(columns={'Unnamed: 0': 'Team'}, inplace=True)
df['FG%'] = (df['FG%'] * 100).round(2)
df['FT%'] = (df['FT%'] * 100).round(2)
df['TO'] = (df['TO'] * -1)


selected_categories = df.iloc[:, :9]
custom_cmap = sns.color_palette("RdYlGn", as_cmap=True)
styled_df = selected_categories.style.background_gradient(cmap=custom_cmap)


display(styled_df)
# Out:
# <style type="text/css">
# #T_ca2a8_row0_col1, #T_ca2a8_row1_col1, #T_ca2a8_row7_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_ca2a8_row0_col2 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_ca2a8_row0_col3 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_ca2a8_row0_col4, #T_ca2a8_row3_col4 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_ca2a8_row0_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_ca2a8_row0_col6, #T_ca2a8_row3_col5 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_ca2a8_row0_col7 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_ca2a8_row0_col8 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_ca2a8_row1_col2, #T_ca2a8_row1_col7, #T_ca2a8_row1_col8, #T_ca2a8_row2_col3, #T_ca2a8_row2_col6, #T_ca2a8_row3_col1, #T_ca2a8_row9_col4, #T_ca2a8_row10_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ca2a8_row1_col3 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_ca2a8_row1_col4 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_ca2a8_row1_col5, #T_ca2a8_row3_col2, #T_ca2a8_row5_col4, #T_ca2a8_row6_col6, #T_ca2a8_row6_col8, #T_ca2a8_row8_col3, #T_ca2a8_row8_col7, #T_ca2a8_row10_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ca2a8_row1_col6 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_ca2a8_row2_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_ca2a8_row2_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_ca2a8_row2_col4 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_ca2a8_row2_col5 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_ca2a8_row2_col7, #T_ca2a8_row10_col7 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_ca2a8_row2_col8 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_ca2a8_row3_col3 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_ca2a8_row3_col6 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_ca2a8_row3_col7 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_ca2a8_row3_col8, #T_ca2a8_row8_col8 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_ca2a8_row4_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_ca2a8_row4_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_ca2a8_row4_col3, #T_ca2a8_row6_col3 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_ca2a8_row4_col4 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_ca2a8_row4_col5 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_ca2a8_row4_col6 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_ca2a8_row4_col7, #T_ca2a8_row9_col7 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_ca2a8_row4_col8 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_ca2a8_row5_col1 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_ca2a8_row5_col2 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_ca2a8_row5_col3, #T_ca2a8_row7_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_ca2a8_row5_col5, #T_ca2a8_row9_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_ca2a8_row5_col6 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_ca2a8_row5_col7 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_ca2a8_row5_col8 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_ca2a8_row6_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_ca2a8_row6_col2 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_ca2a8_row6_col4 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_ca2a8_row6_col5, #T_ca2a8_row9_col3 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_ca2a8_row6_col7 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_ca2a8_row7_col2 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_ca2a8_row7_col4 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_ca2a8_row7_col5 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_ca2a8_row7_col6 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_ca2a8_row7_col7 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_ca2a8_row7_col8, #T_ca2a8_row10_col4 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_ca2a8_row8_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_ca2a8_row8_col2 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_ca2a8_row8_col4 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_ca2a8_row8_col5 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_ca2a8_row8_col6 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_ca2a8_row9_col2 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_ca2a8_row9_col5 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_ca2a8_row9_col6 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_ca2a8_row9_col8 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_ca2a8_row10_col2 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_ca2a8_row10_col3 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_ca2a8_row10_col6 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_ca2a8_row10_col8 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_ca2a8_row11_col1 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_ca2a8_row11_col2 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_ca2a8_row11_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_ca2a8_row11_col4 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_ca2a8_row11_col5 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_ca2a8_row11_col6 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_ca2a8_row11_col7 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_ca2a8_row11_col8 {
#   background-color: #feec9f;
#   color: #000000;
# }
# </style>
# <table id="T_ca2a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca2a8_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_ca2a8_level0_col1" class="col_heading level0 col1" >FG%</th>
#       <th id="T_ca2a8_level0_col2" class="col_heading level0 col2" >FT%</th>
#       <th id="T_ca2a8_level0_col3" class="col_heading level0 col3" >3PM</th>
#       <th id="T_ca2a8_level0_col4" class="col_heading level0 col4" >REB</th>
#       <th id="T_ca2a8_level0_col5" class="col_heading level0 col5" >AST</th>
#       <th id="T_ca2a8_level0_col6" class="col_heading level0 col6" >STL</th>
#       <th id="T_ca2a8_level0_col7" class="col_heading level0 col7" >BLK</th>
#       <th id="T_ca2a8_level0_col8" class="col_heading level0 col8" >TO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca2a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca2a8_row0_col0" class="data row0 col0" >RIZZ</td>
#       <td id="T_ca2a8_row0_col1" class="data row0 col1" >47.100000</td>
#       <td id="T_ca2a8_row0_col2" class="data row0 col2" >77.170000</td>
#       <td id="T_ca2a8_row0_col3" class="data row0 col3" >37</td>
#       <td id="T_ca2a8_row0_col4" class="data row0 col4" >163</td>
#       <td id="T_ca2a8_row0_col5" class="data row0 col5" >91</td>
#       <td id="T_ca2a8_row0_col6" class="data row0 col6" >27</td>
#       <td id="T_ca2a8_row0_col7" class="data row0 col7" >29</td>
#       <td id="T_ca2a8_row0_col8" class="data row0 col8" >-55</td>
#     </tr>
#     <tr>
#       <th id="T_ca2a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca2a8_row1_col0" class="data row1 col0" >RAO</td>
#       <td id="T_ca2a8_row1_col1" class="data row1 col1" >47.120000</td>
#       <td id="T_ca2a8_row1_col2" class="data row1 col2" >87.230000</td>
#       <td id="T_ca2a8_row1_col3" class="data row1 col3" >35</td>
#       <td id="T_ca2a8_row1_col4" class="data row1 col4" >178</td>
#       <td id="T_ca2a8_row1_col5" class="data row1 col5" >71</td>
#       <td id="T_ca2a8_row1_col6" class="data row1 col6" >30</td>
#       <td id="T_ca2a8_row1_col7" class="data row1 col7" >33</td>
#       <td id="T_ca2a8_row1_col8" class="data row1 col8" >-41</td>
#     </tr>
#     <tr>
#       <th id="T_ca2a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca2a8_row2_col0" class="data row2 col0" >OVJG</td>
#       <td id="T_ca2a8_row2_col1" class="data row2 col1" >46.080000</td>
#       <td id="T_ca2a8_row2_col2" class="data row2 col2" >86.670000</td>
#       <td id="T_ca2a8_row2_col3" cl

# %%
stat_categories = df.columns[1:]
rank_df = df.copy()
rank_df[stat_categories] = rank_df[stat_categories].rank(ascending=False, method='min').astype(int)

sort_category = "FG%"

rank_df = rank_df.sort_values(by = sort_category)
display(rank_df)
# Out:
#     Team  FG%  FT%  3PM  REB  AST  STL  BLK  TO  PTS  Mins  Games
# 3   GOAt    1   12   11    9   10   11    8   7   10    12     12
# 6    uwu    2    3    3    4    7   12    2  12    1     3      7
# 9    BBB    3   11    8    1    4    2    4   9    7     5      1
# 11  KOCE    4   10    7    3    6    4    7   6    6     6      7
# 1    RAO    5    1   10    7   12    6    1   1   12    11     10
# 0   RIZZ    6    7    9    9    9    9    3   2    5     8      1
# 7    GRU    7    6    5    2   11   10    6   3    8     7      5
# 4    POG    8    9    3    6    2    8    4  10    3     4      5
# 2   OVJG    9    2    1   11    8    1    9   5    4     2      1
# 8   ZHAN   10    5   12    8    5    5   12   7    9    10     11
# 5   MTDT   11    4    5   12    3    3   11   4   11     9      7
# 10    VR   12    8    2    5    1    7    9  11    2     1      1

# %%
average_df = df.copy()
for category in stat_categories:
    # Calculate the average by dividing the value by the number of games
    average_df[category] = (average_df[category] / average_df['Games']).round(2)

# Drop the 'Games' column as it's no longer needed
average_df.drop(columns=['Games'], inplace=True)

# Display the DataFrame with average values
average_df
# Out:
#     Team   FG%   FT%   3PM   REB   AST   STL   BLK    TO    PTS   Mins
# 0   RIZZ  1.43  2.34  1.12  4.94  2.76  0.82  0.88 -1.67  16.39  27.76
# 1    RAO  1.57  2.91  1.17  5.93  2.37  1.00  1.10 -1.37  13.70  28.03
# 2   OVJG  1.40  2.63  2.18  4.82  2.94  1.18  0.45 -1.85  16.67  31.06
# 3   GOAt  1.90  2.41  1.21  5.82  3.18  0.89  0.71 -2.32  15.79  29.89
# 4    POG  1.45  2.30  1.88  5.78  4.41  0.88  0.88 -2.47  17.66  31.28
# 5   MTDT  1.35  2.64  1.74  4.32  4.45  1.19  0.32 -1.87  13.39  29.23
# 6    uwu  1.63  2.70  1.94  6.74  3.35  0.77  1.00 -2.65  20.00  32.94
# 7    GRU  1.47  2.43  1.69  6.62  2.72  0.81  0.78 -1.75  14.88  28.66
# 8   ZHAN  1.51  2.78  0.90  5.72  4.21  1.14  0.28 -2.24  15.66  29.90
# 9    BBB  1.51  2.15  1.30  7.12  4.00  1.15  0.85 -2.00  14.94  28.91
# 10    VR  1.20  2.31  2.09  6.00  4.85  0.88  0.45 -2.45  17.15  32.88
# 11  KOCE  1.53  2.35  1.42  6.81  3.90  1.10  0.68 -2.06  16.23  29.68

# %%
teams = df['Team']
num_teams = len(teams)
score_data = []
row_total = []
for i in range(num_teams):
    team_a = teams[i]
    row = []
    wins = 0
    losses = 0
    draws = 0
    for j in range(num_teams):
        team_b = teams[j]
        if team_a == team_b:
            row.append(0)
        else:
            team_a_wins = sum(df.iloc[i, 1:10] > df.iloc[j, 1:10])
            team_b_wins = sum(df.iloc[i, 1:10] < df.iloc[j, 1:10])
            team_draw = sum(df.iloc[i, 1:10] == df.iloc[j, 1:10])
            score = f"{team_a_wins} - {team_b_wins} - {team_draw}"
            if team_a_wins > team_b_wins:
                row.append(f'<span style="color:green">{score}</span>')
                wins += 1
            elif team_b_wins > team_a_wins: 
                row.append(f'<span style="color:red">{score}</span>' )
                losses += 1
            else:
                row.append(score)
                draws +=1
                
    score_data.append(row)
    row_total.append(f"{wins} - {losses} - {draws}")

score_df = pd.DataFrame(score_data, columns=teams, index=teams)
score_df['Win Total'] = row_total


score_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_5887e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th id="T_5887e_level0_col0" class="col_heading level0 col0" >RIZZ</th>
#       <th id="T_5887e_level0_col1" class="col_heading level0 col1" >RAO</th>
#       <th id="T_5887e_level0_col2" class="col_heading level0 col2" >OVJG</th>
#       <th id="T_5887e_level0_col3" class="col_heading level0 col3" >GOAt</th>
#       <th id="T_5887e_level0_col4" class="col_heading level0 col4" >POG</th>
#       <th id="T_5887e_level0_col5" class="col_heading level0 col5" >MTDT</th>
#       <th id="T_5887e_level0_col6" class="col_heading level0 col6" >uwu</th>
#       <th id="T_5887e_level0_col7" class="col_heading level0 col7" >GRU</th>
#       <th id="T_5887e_level0_col8" class="col_heading level0 col8" >ZHAN</th>
#       <th id="T_5887e_level0_col9" class="col_heading level0 col9" >BBB</th>
#       <th id="T_5887e_level0_col10" class="col_heading level0 col10" >VR</th>
#       <th id="T_5887e_level0_col11" class="col_heading level0 col11" >KOCE</th>
#       <th id="T_5887e_level0_col12" class="col_heading level0 col12" >Win Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5887e_level0_row0" class="row_heading level0 row0" >RIZZ</th>
#       <td id="T_5887e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5887e_row0_col1" class="data row0 col1" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_5887e_row0_col2" class="data row0 col2" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row0_col3" class="data row0 col3" ><span style="color:green">7 - 1 - 1</span></td>
#       <td id="T_5887e_row0_col4" class="data row0 col4" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row0_col5" class="data row0 col5" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row0_col6" class="data row0 col6" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_5887e_row0_col7" class="data row0 col7" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_5887e_row0_col8" class="data row0 col8" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row0_col9" class="data row0 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row0_col10" class="data row0 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row0_col11" class="data row0 col11" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row0_col12" class="data row0 col12" >4 - 7 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_5887e_level0_row1" class="row_heading level0 row1" >RAO</th>
#       <td id="T_5887e_row1_col0" class="data row1 col0" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_5887e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_5887e_row1_col2" class="data row1 col2" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row1_col3" class="data row1 col3" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_5887e_row1_col4" class="data row1 col4" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row1_col5" class="data row1 col5" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row1_col6" class="data row1 col6" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row1_col7" class="data row1 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row1_col8" class="data row1 col8" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_5887e_row1_col9" class="data row1 col9" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_5887e_row1_col10" class="data row1 col10" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row1_col11" class="data row1 col11" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_5887e_row1_col12" class="data row1 col12" >8 - 3 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_5887e_level0_row2" class="row_heading level0 row2" >OVJG</th>
#       <td id="T_5887e_row2_col0" class="data row2 col0" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row2_col1" class="data row2 col1" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_5887e_row2_col3" class="data row2 col3" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_5887e_row2_col4" class="data row2 col4" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row2_col5" class="data row2 col5" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_5887e_row2_col6" class="data row2 col6" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row2_col7" class="data row2 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row2_col8" class="data row2 col8" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_5887e_row2_col9" class="data row2 col9" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row2_col10" class="data row2 col10" ><span style="color:green">5 - 3 - 1</span></td>
#       <td id="T_5887e_row2_col11" class="data row2 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row2_col12" class="data row2 col12" >8 - 3 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_5887e_level0_row3" class="row_heading level0 row3" >GOAt</th>
#       <td id="T_5887e_row3_col0" class="data row3 col0" ><span style="color:red">1 - 7 - 1</span></td>
#       <td id="T_5887e_row3_col1" class="data row3 col1" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_5887e_row3_col2" class="data row3 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_5887e_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_5887e_row3_col4" class="data row3 col4" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_5887e_row3_col5" class="data row3 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row3_col6" class="data row3 col6" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_5887e_row3_col7" class="data row3 col7" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_5887e_row3_col8" class="data row3 col8" ><span style="color:red">3 - 5 - 1</span></td>
#       <td id="T_5887e_row3_col9" class="data row3 col9" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_5887e_row3_col10" class="data row3 col10" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_5887e_row3_col11" class="data row3 col11" ><span style="color:red">1 - 8 - 0</span></td>
#       <td id="T_5887e_row3_col12" class="data row3 col12" >0 - 11 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_5887e_level0_row4" class="row_heading level0 row4" >POG</th>
#       <td id="T_5887e_row4_col0" class="data row4 col0" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row4_col1" class="data row4 col1" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_5887e_row4_col2" class="data row4 col2" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_5887e_row4_col3" class="data row4 col3" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_5887e_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_5887e_row4_col5" class="data row4 col5" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T

# %% [markdown]
# Average per game

# %%
teams = df['Team']
num_teams = len(teams)
score_data = []
row_total = []
for i in range(num_teams):
    team_a = teams[i]
    row = []
    wins = 0
    losses = 0
    draws = 0
    for j in range(num_teams):
        team_b = teams[j]
        if team_a == team_b:
            row.append(0)
        else:
            team_a_wins = sum(average_df.iloc[i, 1:10] > average_df.iloc[j, 1:10])
            team_b_wins = sum(average_df.iloc[i, 1:10] < average_df.iloc[j, 1:10])
            team_draw = sum(average_df.iloc[i, 1:10] == average_df.iloc[j, 1:10])
            score = f"{team_a_wins} - {team_b_wins} - {team_draw}"
            if team_a_wins > team_b_wins:
                row.append(f'<span style="color:green">{score}</span>')
                wins += 1
            elif team_b_wins > team_a_wins: 
                row.append(f'<span style="color:red">{score}</span>' )
                losses += 1
            else:
                row.append(score)
                draws +=1
                
    score_data.append(row)
    row_total.append(f"{wins} - {losses} - {draws}")

score_average_df = pd.DataFrame(score_data, columns=teams, index=teams)
score_average_df['Win Total'] = row_total


score_average_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_317ba">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th id="T_317ba_level0_col0" class="col_heading level0 col0" >RIZZ</th>
#       <th id="T_317ba_level0_col1" class="col_heading level0 col1" >RAO</th>
#       <th id="T_317ba_level0_col2" class="col_heading level0 col2" >OVJG</th>
#       <th id="T_317ba_level0_col3" class="col_heading level0 col3" >GOAt</th>
#       <th id="T_317ba_level0_col4" class="col_heading level0 col4" >POG</th>
#       <th id="T_317ba_level0_col5" class="col_heading level0 col5" >MTDT</th>
#       <th id="T_317ba_level0_col6" class="col_heading level0 col6" >uwu</th>
#       <th id="T_317ba_level0_col7" class="col_heading level0 col7" >GRU</th>
#       <th id="T_317ba_level0_col8" class="col_heading level0 col8" >ZHAN</th>
#       <th id="T_317ba_level0_col9" class="col_heading level0 col9" >BBB</th>
#       <th id="T_317ba_level0_col10" class="col_heading level0 col10" >VR</th>
#       <th id="T_317ba_level0_col11" class="col_heading level0 col11" >KOCE</th>
#       <th id="T_317ba_level0_col12" class="col_heading level0 col12" >Win Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_317ba_level0_row0" class="row_heading level0 row0" >RIZZ</th>
#       <td id="T_317ba_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_317ba_row0_col1" class="data row0 col1" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_317ba_row0_col2" class="data row0 col2" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row0_col3" class="data row0 col3" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_317ba_row0_col4" class="data row0 col4" ><span style="color:red">2 - 6 - 1</span></td>
#       <td id="T_317ba_row0_col5" class="data row0 col5" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row0_col6" class="data row0 col6" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_317ba_row0_col7" class="data row0 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row0_col8" class="data row0 col8" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row0_col9" class="data row0 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row0_col10" class="data row0 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row0_col11" class="data row0 col11" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_317ba_row0_col12" class="data row0 col12" >2 - 9 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_317ba_level0_row1" class="row_heading level0 row1" >RAO</th>
#       <td id="T_317ba_row1_col0" class="data row1 col0" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_317ba_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_317ba_row1_col2" class="data row1 col2" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row1_col3" class="data row1 col3" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row1_col4" class="data row1 col4" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_317ba_row1_col5" class="data row1 col5" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_317ba_row1_col6" class="data row1 col6" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row1_col7" class="data row1 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row1_col8" class="data row1 col8" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_317ba_row1_col9" class="data row1 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row1_col10" class="data row1 col10" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row1_col11" class="data row1 col11" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row1_col12" class="data row1 col12" >8 - 3 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_317ba_level0_row2" class="row_heading level0 row2" >OVJG</th>
#       <td id="T_317ba_row2_col0" class="data row2 col0" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row2_col1" class="data row2 col1" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_317ba_row2_col3" class="data row2 col3" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row2_col4" class="data row2 col4" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row2_col5" class="data row2 col5" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_317ba_row2_col6" class="data row2 col6" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_317ba_row2_col7" class="data row2 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row2_col8" class="data row2 col8" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row2_col9" class="data row2 col9" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row2_col10" class="data row2 col10" ><span style="color:green">5 - 3 - 1</span></td>
#       <td id="T_317ba_row2_col11" class="data row2 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row2_col12" class="data row2 col12" >8 - 3 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_317ba_level0_row3" class="row_heading level0 row3" >GOAt</th>
#       <td id="T_317ba_row3_col0" class="data row3 col0" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_317ba_row3_col1" class="data row3 col1" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row3_col2" class="data row3 col2" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_317ba_row3_col4" class="data row3 col4" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row3_col5" class="data row3 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row3_col6" class="data row3 col6" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_317ba_row3_col7" class="data row3 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row3_col8" class="data row3 col8" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row3_col9" class="data row3 col9" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_317ba_row3_col10" class="data row3 col10" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row3_col11" class="data row3 col11" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_317ba_row3_col12" class="data row3 col12" >4 - 7 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_317ba_level0_row4" class="row_heading level0 row4" >POG</th>
#       <td id="T_317ba_row4_col0" class="data row4 col0" ><span style="color:green">6 - 2 - 1</span></td>
#       <td id="T_317ba_row4_col1" class="data row4 col1" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_317ba_row4_col2" class="data row4 col2" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_317ba_row4_col3" class="data row4 col3" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_317ba_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_317ba_row4_col5" class="data row4 col5" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="

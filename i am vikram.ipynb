# %%
import numpy as np
import pandas as pd 
from IPython.display import display
import os 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('fantasybball.xlsx', "Week 5", engine='openpyxl')

df.rename(columns={'Unnamed: 0': 'Team'}, inplace=True)
df['FG%'] = (df['FG%'] * 100).round(2)
df['FT%'] = (df['FT%'] * 100).round(2)
df['TO'] = (df['TO'] * -1)


selected_categories = df.iloc[:, :9]
custom_cmap = sns.color_palette("RdYlGn", as_cmap=True)
styled_df = selected_categories.style.background_gradient(cmap=custom_cmap)


display(styled_df)
# Out:
# <style type="text/css">
# #T_4d4d7_row0_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_4d4d7_row0_col2 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_4d4d7_row0_col3, #T_4d4d7_row1_col2 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_4d4d7_row0_col4 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_4d4d7_row0_col5 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_4d4d7_row0_col6, #T_4d4d7_row0_col7, #T_4d4d7_row2_col6, #T_4d4d7_row2_col8, #T_4d4d7_row4_col4, #T_4d4d7_row6_col1, #T_4d4d7_row7_col5, #T_4d4d7_row10_col2, #T_4d4d7_row11_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4d4d7_row0_col8, #T_4d4d7_row5_col8 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_4d4d7_row1_col1 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_4d4d7_row1_col3 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_4d4d7_row1_col4, #T_4d4d7_row3_col4, #T_4d4d7_row6_col8 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_4d4d7_row1_col5 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_4d4d7_row1_col6, #T_4d4d7_row4_col6 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_4d4d7_row1_col7 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_4d4d7_row1_col8 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_4d4d7_row2_col1 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_4d4d7_row2_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_4d4d7_row2_col3 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_4d4d7_row2_col4, #T_4d4d7_row9_col2 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_4d4d7_row2_col5, #T_4d4d7_row9_col4, #T_4d4d7_row11_col5 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_4d4d7_row2_col7, #T_4d4d7_row3_col5, #T_4d4d7_row3_col8, #T_4d4d7_row4_col2, #T_4d4d7_row4_col3, #T_4d4d7_row5_col1, #T_4d4d7_row9_col6, #T_4d4d7_row10_col1, #T_4d4d7_row11_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4d4d7_row3_col1, #T_4d4d7_row11_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_4d4d7_row3_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_4d4d7_row3_col3 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_4d4d7_row3_col6 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_4d4d7_row3_col7 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_4d4d7_row4_col1 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_4d4d7_row4_col5 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_4d4d7_row4_col7, #T_4d4d7_row9_col7 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_4d4d7_row4_col8 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_4d4d7_row5_col2 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_4d4d7_row5_col3, #T_4d4d7_row7_col6, #T_4d4d7_row10_col8, #T_4d4d7_row11_col6 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_4d4d7_row5_col4 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_4d4d7_row5_col5 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_4d4d7_row5_col6, #T_4d4d7_row7_col8 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_4d4d7_row5_col7 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_4d4d7_row6_col2 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_4d4d7_row6_col3 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_4d4d7_row6_col4 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_4d4d7_row6_col5, #T_4d4d7_row7_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_4d4d7_row6_col6 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_4d4d7_row6_col7 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_4d4d7_row7_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_4d4d7_row7_col2 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_4d4d7_row7_col3, #T_4d4d7_row10_col3 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_4d4d7_row7_col7, #T_4d4d7_row10_col7, #T_4d4d7_row11_col7 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_4d4d7_row8_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_4d4d7_row8_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_4d4d7_row8_col3 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_4d4d7_row8_col4 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_4d4d7_row8_col5 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_4d4d7_row8_col6 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_4d4d7_row8_col7 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_4d4d7_row8_col8 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_4d4d7_row9_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_4d4d7_row9_col3 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_4d4d7_row9_col5 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_4d4d7_row9_col8 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_4d4d7_row10_col4 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_4d4d7_row10_col5 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_4d4d7_row10_col6 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_4d4d7_row11_col1 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_4d4d7_row11_col8 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# </style>
# <table id="T_4d4d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d4d7_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_4d4d7_level0_col1" class="col_heading level0 col1" >FG%</th>
#       <th id="T_4d4d7_level0_col2" class="col_heading level0 col2" >FT%</th>
#       <th id="T_4d4d7_level0_col3" class="col_heading level0 col3" >3PM</th>
#       <th id="T_4d4d7_level0_col4" class="col_heading level0 col4" >REB</th>
#       <th id="T_4d4d7_level0_col5" class="col_heading level0 col5" >AST</th>
#       <th id="T_4d4d7_level0_col6" class="col_heading level0 col6" >STL</th>
#       <th id="T_4d4d7_level0_col7" class="col_heading level0 col7" >BLK</th>
#       <th id="T_4d4d7_level0_col8" class="col_heading level0 col8" >TO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d4d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d4d7_row0_col0" class="data row0 col0" >OVJG</td>
#       <td id="T_4d4d7_row0_col1" class="data row0 col1" >43.750000</td>
#       <td id="T_4d4d7_row0_col2" class="data row0 col2" >85.950000</td>
#       <td id="T_4d4d7_row0_col3" class="data row0 col3" >70</td>
#       <td id="T_4d4d7_row0_col4" class="data row0 col4" >150</td>
#       <td id="T_4d4d7_row0_col5" class="data row0 col5" >133</td>
#       <td id="T_4d4d7_row0_col6" class="data row0 col6" >26</td>
#       <td id="T_4d4d7_row0_col7" class="data row0 col7" >11</td>
#       <td id="T_4d4d7_row0_col8" class="data row0 col8" >-66</td>
#     </tr>
#     <tr>
#       <th id="T_4d4d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4d4d7_row1_col0" class="data row1 col0" >RAO</td>
#       <td id="T_4d4d7_row1_col1" class="data row1 col1" >47.100000</td>
#       <td id="T_4d4d7_row1_col2" class="data row1 col2" >82.030000</td>
#       <td id="T_4d4d7_row1_col3" class="data row1 col3" >38</td>
#       <td id="T_4d4d7_row1_col4" class="data row1 col4" >198</td>
#       <td id="T_4d4d7_row1_col5" class="data row1 col5" >97</td>
#       <td id="T_4d4d7_row1_col6" class="data row1 col6" >34</td>
#       <td id="T_4d4d7_row1_col7" class="data row1 col7" >28</td>
#       <td id="T_4d4d7_row1_col8" class="data row1 col8" >-52</td>
#     </tr>
#     <tr>
#       <th id="T_4d4d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4d4d7_row2_col0" class="data row2 col0" >POG</td>
#       <td id="T_4d4d7_row2_col1" class="data row2 col1" >48.830000</td>
#       <td id="T_4d4d7_row2_col2" class="data row2 col2" >84.180000</td>
#       <td id="T_4d4d7_row2_col3" class="data row2 col3" >52</td>
#       <td id="T_4d4d7_row2_col4" class="data row2 col4" >205</td>
#       <td id="T_4d4d7_row2_col5" class="data row2 col5" >134</td>
#       <td id="T_4d4d7_row2_col6" class="data row2 col6" >26</td>
#       <td id="T_4d4d7_row2_col7" class="data row2 col7" >33</td>
#       <td id="T_4d4d7_row2_col8" class="data row2 col8" >-82</td>
#     </tr>
#     <tr>
#       <th id="T_4d4d7_l

# %%
stat_categories = df.columns[1:]
rank_df = df.copy()
rank_df[stat_categories] = rank_df[stat_categories].rank(ascending=False, method='min').astype(int)

sort_category = "FG%"

rank_df = rank_df.sort_values(by = sort_category)
display(rank_df)
# Out:
#     Team  FG%  FT%  3PM  REB  AST  STL  BLK  TO  PTS  Mins  Games
# 10  KOCE    1   12    8    3   10    9    2  10    6     7      1
# 5   GOAt    2   11    4    9    9    2   10   8    3     9      1
# 9    uwu    3    5    7    5    3    1    8  11    4     4      1
# 4   MTDT    4    1    1   12    4    3    8   4    2    10     12
# 7    GRU    5   10    8    2   12    6    2   2   11    12      9
# 2    POG    6    4    6    4    6   11    1  12    5     2      1
# 8     VR    7    8    2    8    5   10    7   7    1     1      1
# 1    RAO    8    6   11    6   11    3    5   3    8     6      9
# 3   RIZZ    9    7   10    6    1    8    6   1    7     3      1
# 11   BBB   10    9   12    1    6    6    2   6   12    11      9
# 0   OVJG   11    2    3   11    8   11   12   8   10     4      1
# 6   ZHAN   12    3    5   10    2    5   11   5    9     8      1

# %%
average_df = df.copy()
for category in stat_categories:
    # Calculate the average by dividing the value by the number of games
    average_df[category] = (average_df[category] / average_df['Games']).round(2)

# Drop the 'Games' column as it's no longer needed
average_df.drop(columns=['Games'], inplace=True)

# Display the DataFrame with average values
average_df
# Out:
#     Team   FG%   FT%   3PM   REB   AST   STL   BLK    TO    PTS   Mins
# 0   OVJG  1.33  2.60  2.12  4.55  4.03  0.79  0.33 -2.00  15.88  31.36
# 1    RAO  1.47  2.56  1.19  6.19  3.03  1.06  0.88 -1.62  17.16  31.91
# 2    POG  1.48  2.55  1.58  6.21  4.06  0.79  1.00 -2.48  18.21  31.79
# 3   RIZZ  1.38  2.46  1.39  6.00  4.67  0.91  0.79 -1.30  17.33  31.55
# 4   MTDT  1.63  2.82  2.90  4.55  4.81  1.10  0.65 -1.71  21.10  31.00
# 5   GOAt  1.56  2.34  1.67  5.45  3.70  1.15  0.55 -2.00  18.48  30.00
# 6   ZHAN  1.26  2.57  1.64  5.36  4.64  0.97  0.39 -1.67  16.06  30.48
# 7    GRU  1.56  2.44  1.50  6.94  2.47  0.97  0.91 -1.44  15.69  29.59
# 8     VR  1.47  2.41  2.18  5.64  4.21  0.82  0.64 -1.97  20.30  32.21
# 9    uwu  1.56  2.54  1.55  6.09  4.55  1.18  0.61 -2.27  18.33  31.36
# 10  KOCE  1.56  2.19  1.45  6.52  3.61  0.85  0.88 -2.03  17.48  30.70
# 11   BBB  1.40  2.44  1.03  6.97  4.19  0.97  0.91 -1.97  15.12  29.78

# %%
teams = df['Team']
num_teams = len(teams)
score_data = []
row_total = []
for i in range(num_teams):
    team_a = teams[i]
    row = []
    wins = 0
    losses = 0
    draws = 0
    for j in range(num_teams):
        team_b = teams[j]
        if team_a == team_b:
            row.append(0)
        else:
            team_a_wins = sum(df.iloc[i, 1:10] > df.iloc[j, 1:10])
            team_b_wins = sum(df.iloc[i, 1:10] < df.iloc[j, 1:10])
            team_draw = sum(df.iloc[i, 1:10] == df.iloc[j, 1:10])
            score = f"{team_a_wins} - {team_b_wins} - {team_draw}"
            if team_a_wins > team_b_wins:
                row.append(f'<span style="color:green">{score}</span>')
                wins += 1
            elif team_b_wins > team_a_wins: 
                row.append(f'<span style="color:red">{score}</span>' )
                losses += 1
            else:
                row.append(score)
                draws +=1
                
    score_data.append(row)
    row_total.append(f"{wins} - {losses} - {draws}")

score_df = pd.DataFrame(score_data, columns=teams, index=teams)
score_df['Win Total'] = row_total


score_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a22c1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th id="T_a22c1_level0_col0" class="col_heading level0 col0" >OVJG</th>
#       <th id="T_a22c1_level0_col1" class="col_heading level0 col1" >RAO</th>
#       <th id="T_a22c1_level0_col2" class="col_heading level0 col2" >POG</th>
#       <th id="T_a22c1_level0_col3" class="col_heading level0 col3" >RIZZ</th>
#       <th id="T_a22c1_level0_col4" class="col_heading level0 col4" >MTDT</th>
#       <th id="T_a22c1_level0_col5" class="col_heading level0 col5" >GOAt</th>
#       <th id="T_a22c1_level0_col6" class="col_heading level0 col6" >ZHAN</th>
#       <th id="T_a22c1_level0_col7" class="col_heading level0 col7" >GRU</th>
#       <th id="T_a22c1_level0_col8" class="col_heading level0 col8" >VR</th>
#       <th id="T_a22c1_level0_col9" class="col_heading level0 col9" >uwu</th>
#       <th id="T_a22c1_level0_col10" class="col_heading level0 col10" >KOCE</th>
#       <th id="T_a22c1_level0_col11" class="col_heading level0 col11" >BBB</th>
#       <th id="T_a22c1_level0_col12" class="col_heading level0 col12" >Win Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a22c1_level0_row0" class="row_heading level0 row0" >OVJG</th>
#       <td id="T_a22c1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a22c1_row0_col1" class="data row0 col1" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_a22c1_row0_col2" class="data row0 col2" ><span style="color:red">3 - 5 - 1</span></td>
#       <td id="T_a22c1_row0_col3" class="data row0 col3" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_a22c1_row0_col4" class="data row0 col4" ><span style="color:red">1 - 8 - 0</span></td>
#       <td id="T_a22c1_row0_col5" class="data row0 col5" ><span style="color:red">3 - 5 - 1</span></td>
#       <td id="T_a22c1_row0_col6" class="data row0 col6" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_a22c1_row0_col7" class="data row0 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row0_col8" class="data row0 col8" ><span style="color:red">1 - 8 - 0</span></td>
#       <td id="T_a22c1_row0_col9" class="data row0 col9" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_a22c1_row0_col10" class="data row0 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row0_col11" class="data row0 col11" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_a22c1_row0_col12" class="data row0 col12" >0 - 11 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_a22c1_level0_row1" class="row_heading level0 row1" >RAO</th>
#       <td id="T_a22c1_row1_col0" class="data row1 col0" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_a22c1_row1_col2" class="data row1 col2" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_a22c1_row1_col3" class="data row1 col3" >4 - 4 - 1</td>
#       <td id="T_a22c1_row1_col4" class="data row1 col4" ><span style="color:red">3 - 5 - 1</span></td>
#       <td id="T_a22c1_row1_col5" class="data row1 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row1_col6" class="data row1 col6" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row1_col7" class="data row1 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row1_col8" class="data row1 col8" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_a22c1_row1_col9" class="data row1 col9" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_a22c1_row1_col10" class="data row1 col10" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_a22c1_row1_col11" class="data row1 col11" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row1_col12" class="data row1 col12" >4 - 6 - 1</td>
#     </tr>
#     <tr>
#       <th id="T_a22c1_level0_row2" class="row_heading level0 row2" >POG</th>
#       <td id="T_a22c1_row2_col0" class="data row2 col0" ><span style="color:green">5 - 3 - 1</span></td>
#       <td id="T_a22c1_row2_col1" class="data row2 col1" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_a22c1_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_a22c1_row2_col3" class="data row2 col3" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row2_col4" class="data row2 col4" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_a22c1_row2_col5" class="data row2 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row2_col6" class="data row2 col6" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row2_col7" class="data row2 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_a22c1_row2_col8" class="data row2 col8" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row2_col9" class="data row2 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row2_col10" class="data row2 col10" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_a22c1_row2_col11" class="data row2 col11" ><span style="color:green">5 - 3 - 1</span></td>
#       <td id="T_a22c1_row2_col12" class="data row2 col12" >6 - 5 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_a22c1_level0_row3" class="row_heading level0 row3" >RIZZ</th>
#       <td id="T_a22c1_row3_col0" class="data row3 col0" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_a22c1_row3_col1" class="data row3 col1" >4 - 4 - 1</td>
#       <td id="T_a22c1_row3_col2" class="data row3 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_a22c1_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_a22c1_row3_col4" class="data row3 col4" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row3_col5" class="data row3 col5" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_a22c1_row3_col6" class="data row3 col6" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row3_col7" class="data row3 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row3_col8" class="data row3 col8" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row3_col9" class="data row3 col9" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_a22c1_row3_col10" class="data row3 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_a22c1_row3_col11" class="data row3 col11" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row3_col12" class="data row3 col12" >5 - 5 - 1</td>
#     </tr>
#     <tr>
#       <th id="T_a22c1_level0_row4" class="row_heading level0 row4" >MTDT</th>
#       <td id="T_a22c1_row4_col0" class="data row4 col0" ><span style="color:green">8 - 1 - 0</span></td>
#       <td id="T_a22c1_row4_col1" class="data row4 col1" ><span style="color:green">5 - 3 - 1</span></td>
#       <td id="T_a22c1_row4_col2" class="data row4 col2" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_a22c1_row4_col3" class="data row4 col3" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_a22c1_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_a22c1_row4_col5" class="data row4 col5" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_a22c1_row4_col6" class="data row4 col6" ><span style="color:green">7

# %% [markdown]
# Average per game

# %%
teams = df['Team']
num_teams = len(teams)
score_data = []
row_total = []
for i in range(num_teams):
    team_a = teams[i]
    row = []
    wins = 0
    losses = 0
    draws = 0
    for j in range(num_teams):
        team_b = teams[j]
        if team_a == team_b:
            row.append(0)
        else:
            team_a_wins = sum(average_df.iloc[i, 1:10] > average_df.iloc[j, 1:10])
            team_b_wins = sum(average_df.iloc[i, 1:10] < average_df.iloc[j, 1:10])
            team_draw = sum(average_df.iloc[i, 1:10] == average_df.iloc[j, 1:10])
            score = f"{team_a_wins} - {team_b_wins} - {team_draw}"
            if team_a_wins > team_b_wins:
                row.append(f'<span style="color:green">{score}</span>')
                wins += 1
            elif team_b_wins > team_a_wins: 
                row.append(f'<span style="color:red">{score}</span>' )
                losses += 1
            else:
                row.append(score)
                draws +=1
                
    score_data.append(row)
    row_total.append(f"{wins} - {losses} - {draws}")

score_average_df = pd.DataFrame(score_data, columns=teams, index=teams)
score_average_df['Win Total'] = row_total


score_average_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_836c4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th id="T_836c4_level0_col0" class="col_heading level0 col0" >OVJG</th>
#       <th id="T_836c4_level0_col1" class="col_heading level0 col1" >RAO</th>
#       <th id="T_836c4_level0_col2" class="col_heading level0 col2" >POG</th>
#       <th id="T_836c4_level0_col3" class="col_heading level0 col3" >RIZZ</th>
#       <th id="T_836c4_level0_col4" class="col_heading level0 col4" >MTDT</th>
#       <th id="T_836c4_level0_col5" class="col_heading level0 col5" >GOAt</th>
#       <th id="T_836c4_level0_col6" class="col_heading level0 col6" >ZHAN</th>
#       <th id="T_836c4_level0_col7" class="col_heading level0 col7" >GRU</th>
#       <th id="T_836c4_level0_col8" class="col_heading level0 col8" >VR</th>
#       <th id="T_836c4_level0_col9" class="col_heading level0 col9" >uwu</th>
#       <th id="T_836c4_level0_col10" class="col_heading level0 col10" >KOCE</th>
#       <th id="T_836c4_level0_col11" class="col_heading level0 col11" >BBB</th>
#       <th id="T_836c4_level0_col12" class="col_heading level0 col12" >Win Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_836c4_level0_row0" class="row_heading level0 row0" >OVJG</th>
#       <td id="T_836c4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_836c4_row0_col1" class="data row0 col1" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row0_col2" class="data row0 col2" ><span style="color:red">3 - 5 - 1</span></td>
#       <td id="T_836c4_row0_col3" class="data row0 col3" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_836c4_row0_col4" class="data row0 col4" ><span style="color:red">0 - 8 - 1</span></td>
#       <td id="T_836c4_row0_col5" class="data row0 col5" ><span style="color:red">3 - 5 - 1</span></td>
#       <td id="T_836c4_row0_col6" class="data row0 col6" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row0_col7" class="data row0 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row0_col8" class="data row0 col8" ><span style="color:red">1 - 8 - 0</span></td>
#       <td id="T_836c4_row0_col9" class="data row0 col9" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row0_col10" class="data row0 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row0_col11" class="data row0 col11" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row0_col12" class="data row0 col12" >0 - 11 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_836c4_level0_row1" class="row_heading level0 row1" >RAO</th>
#       <td id="T_836c4_row1_col0" class="data row1 col0" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_836c4_row1_col2" class="data row1 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row1_col3" class="data row1 col3" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_836c4_row1_col4" class="data row1 col4" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row1_col5" class="data row1 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row1_col6" class="data row1 col6" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row1_col7" class="data row1 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row1_col8" class="data row1 col8" ><span style="color:green">5 - 3 - 1</span></td>
#       <td id="T_836c4_row1_col9" class="data row1 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row1_col10" class="data row1 col10" ><span style="color:red">3 - 5 - 1</span></td>
#       <td id="T_836c4_row1_col11" class="data row1 col11" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row1_col12" class="data row1 col12" >5 - 6 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_836c4_level0_row2" class="row_heading level0 row2" >POG</th>
#       <td id="T_836c4_row2_col0" class="data row2 col0" ><span style="color:green">5 - 3 - 1</span></td>
#       <td id="T_836c4_row2_col1" class="data row2 col1" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_836c4_row2_col3" class="data row2 col3" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row2_col4" class="data row2 col4" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_836c4_row2_col5" class="data row2 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row2_col6" class="data row2 col6" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row2_col7" class="data row2 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_836c4_row2_col8" class="data row2 col8" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row2_col9" class="data row2 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row2_col10" class="data row2 col10" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_836c4_row2_col11" class="data row2 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_836c4_row2_col12" class="data row2 col12" >6 - 5 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_836c4_level0_row3" class="row_heading level0 row3" >RIZZ</th>
#       <td id="T_836c4_row3_col0" class="data row3 col0" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_836c4_row3_col1" class="data row3 col1" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row3_col2" class="data row3 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_836c4_row3_col4" class="data row3 col4" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row3_col5" class="data row3 col5" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_836c4_row3_col6" class="data row3 col6" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row3_col7" class="data row3 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row3_col8" class="data row3 col8" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row3_col9" class="data row3 col9" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_836c4_row3_col10" class="data row3 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_836c4_row3_col11" class="data row3 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_836c4_row3_col12" class="data row3 col12" >5 - 6 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_836c4_level0_row4" class="row_heading level0 row4" >MTDT</th>
#       <td id="T_836c4_row4_col0" class="data row4 col0" ><span style="color:green">8 - 0 - 1</span></td>
#       <td id="T_836c4_row4_col1" class="data row4 col1" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row4_col2" class="data row4 col2" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_836c4_row4_col3" class="data row4 col3" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_836c4_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_836c4_row4_col5" class="data row4 col5" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_836c4

# %%
import numpy as np
import pandas as pd 
from IPython.display import display
import os 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('fantasybball.xlsx', "Week 6", engine='openpyxl')

df.rename(columns={'Unnamed: 0': 'Team'}, inplace=True)
df['FG%'] = (df['FG%'] * 100).round(2)
df['FT%'] = (df['FT%'] * 100).round(2)
df['TO'] = (df['TO'] * -1)


selected_categories = df.iloc[:, :9]
custom_cmap = sns.color_palette("RdYlGn", as_cmap=True)
styled_df = selected_categories.style.background_gradient(cmap=custom_cmap)


display(styled_df)
# Out:
# <style type="text/css">
# #T_98f85_row0_col1 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_98f85_row0_col2, #T_98f85_row6_col8 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_98f85_row0_col3 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_98f85_row0_col4 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_98f85_row0_col5 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_98f85_row0_col6 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_98f85_row0_col7, #T_98f85_row1_col8, #T_98f85_row3_col5, #T_98f85_row4_col1, #T_98f85_row5_col4, #T_98f85_row6_col3, #T_98f85_row9_col6, #T_98f85_row10_col2, #T_98f85_row10_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_98f85_row0_col8 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_98f85_row1_col1, #T_98f85_row7_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_98f85_row1_col2 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_98f85_row1_col3 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_98f85_row1_col4 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_98f85_row1_col5, #T_98f85_row1_col6, #T_98f85_row3_col8, #T_98f85_row4_col3, #T_98f85_row5_col2, #T_98f85_row9_col7, #T_98f85_row10_col1, #T_98f85_row10_col4, #T_98f85_row10_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_98f85_row1_col7, #T_98f85_row4_col5, #T_98f85_row11_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_98f85_row2_col1 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_98f85_row2_col2 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_98f85_row2_col3 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_98f85_row2_col4 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_98f85_row2_col5 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_98f85_row2_col6, #T_98f85_row4_col6 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_98f85_row2_col7 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_98f85_row2_col8 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_98f85_row3_col1 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_98f85_row3_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_98f85_row3_col3, #T_98f85_row11_col8 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_98f85_row3_col4 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_98f85_row3_col6 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_98f85_row3_col7 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_98f85_row4_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_98f85_row4_col4 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_98f85_row4_col7 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_98f85_row4_col8, #T_98f85_row7_col8 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_98f85_row5_col1 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_98f85_row5_col3 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_98f85_row5_col5, #T_98f85_row11_col6 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_98f85_row5_col6 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_98f85_row5_col7 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_98f85_row5_col8, #T_98f85_row10_col8 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_98f85_row6_col1 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_98f85_row6_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_98f85_row6_col4 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_98f85_row6_col5 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_98f85_row6_col6 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_98f85_row6_col7 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_98f85_row7_col1 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_98f85_row7_col3 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_98f85_row7_col4 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_98f85_row7_col5 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_98f85_row7_col6 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_98f85_row7_col7 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_98f85_row8_col1 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_98f85_row8_col2 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_98f85_row8_col3 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_98f85_row8_col4 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_98f85_row8_col5 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_98f85_row8_col6 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_98f85_row8_col7 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_98f85_row8_col8 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_98f85_row9_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_98f85_row9_col2 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_98f85_row9_col3 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_98f85_row9_col4 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_98f85_row9_col5 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_98f85_row9_col8 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_98f85_row10_col5 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_98f85_row10_col6 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_98f85_row11_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_98f85_row11_col3 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_98f85_row11_col4 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_98f85_row11_col5 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_98f85_row11_col7 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_98f85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98f85_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_98f85_level0_col1" class="col_heading level0 col1" >FG%</th>
#       <th id="T_98f85_level0_col2" class="col_heading level0 col2" >FT%</th>
#       <th id="T_98f85_level0_col3" class="col_heading level0 col3" >3PM</th>
#       <th id="T_98f85_level0_col4" class="col_heading level0 col4" >REB</th>
#       <th id="T_98f85_level0_col5" class="col_heading level0 col5" >AST</th>
#       <th id="T_98f85_level0_col6" class="col_heading level0 col6" >STL</th>
#       <th id="T_98f85_level0_col7" class="col_heading level0 col7" >BLK</th>
#       <th id="T_98f85_level0_col8" class="col_heading level0 col8" >TO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98f85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98f85_row0_col0" class="data row0 col0" >RAO</td>
#       <td id="T_98f85_row0_col1" class="data row0 col1" >48.280000</td>
#       <td id="T_98f85_row0_col2" class="data row0 col2" >81.100000</td>
#       <td id="T_98f85_row0_col3" class="data row0 col3" >45</td>
#       <td id="T_98f85_row0_col4" class="data row0 col4" >179</td>
#       <td id="T_98f85_row0_col5" class="data row0 col5" >82</td>
#       <td id="T_98f85_row0_col6" class="data row0 col6" >26</td>
#       <td id="T_98f85_row0_col7" class="data row0 col7" >37</td>
#       <td id="T_98f85_row0_col8" class="data row0 col8" >-43</td>
#     </tr>
#     <tr>
#       <th id="T_98f85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98f85_row1_col0" class="data row1 col0" >GRU</td>
#       <td id="T_98f85_row1_col1" class="data row1 col1" >46.910000</td>
#       <td id="T_98f85_row1_col2" class="data row1 col2" >84.850000</td>
#       <td id="T_98f85_row1_col3" class="data row1 col3" >33</td>
#       <td id="T_98f85_row1_col4" class="data row1 col4" >183</td>
#       <td id="T_98f85_row1_col5" class="data row1 col5" >62</td>
#       <td id="T_98f85_row1_col6" class="data row1 col6" >22</td>
#       <td id="T_98f85_row1_col7" class="data row1 col7" >25</td>
#       <td id="T_98f85_row1_col8" class="data row1 col8" >-34</td>
#     </tr>
#     <tr>
#       <th id="T_98f85_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98f85_row2_col0" class="data row2 col0" >RIZZ</td>
#       <td id="T_98f85_row2_col1" class="data row2 col1" >49.550000</td>
#       <td id="T_98f85_row2_col2" class="data row2 col2" >8

# %%
stat_categories = df.columns[1:]
rank_df = df.copy()
rank_df[stat_categories] = rank_df[stat_categories].rank(ascending=False, method='min').astype(int)

sort_category = "FG%"

rank_df = rank_df.sort_values(by = sort_category)
display(rank_df)
# Out:
#     Team  FG%  FT%  3PM  REB  AST  STL  BLK  TO  PTS  Mins  Games
# 4   GOAt    1    6   12    9   10    4    8   7   11    10     11
# 5    BBB    2   12    9    1    5    6    2   9    4     2      1
# 3    uwu    3   11    7    3    1    2    4  12    6     6      2
# 2   RIZZ    4    2   10   10    7    4    6   3    3     9      9
# 7   KOCE    5   10    6    2    6    9    3   7    8     1      2
# 8    POG    6    4    5    6    2    8    7   5    7     7      2
# 0    RAO    7    7    8    8   11   11    1   2   10    12     12
# 6   MTDT    8    8    1   11    3   10   10   4    5     8      8
# 11  ZHAN    9    3    4    4    9    3    9  11    1     5      2
# 1    GRU   10    5   11    7   12   12    5   1   12    11      9
# 9     VR   11    9    3    5    4    1   11   6    2     4      2
# 10  OVJG   12    1    1   12    8    7   11   9    9     2      2

# %%
average_df = df.copy()
for category in stat_categories:
    # Calculate the average by dividing the value by the number of games
    average_df[category] = (average_df[category] / average_df['Games']).round(2)

# Drop the 'Games' column as it's no longer needed
average_df.drop(columns=['Games'], inplace=True)

# Display the DataFrame with average values
average_df
# Out:
#     Team   FG%   FT%   3PM   REB   AST   STL   BLK    TO    PTS   Mins
# 0    RAO  1.72  2.90  1.61  6.39  2.93  0.93  1.32 -1.54  18.29  29.25
# 1    GRU  1.56  2.83  1.10  6.10  2.07  0.73  0.83 -1.13  12.57  28.43
# 2   RIZZ  1.65  2.88  1.43  5.47  4.57  1.10  0.80 -1.87  19.57  32.00
# 3    uwu  1.51  2.37  1.39  6.73  4.85  1.06  0.85 -2.45  17.30  31.21
# 4   GOAt  1.79  2.86  1.07  5.72  3.90  1.14  0.76 -2.14  16.69  30.66
# 5    BBB  1.41  2.04  1.22  6.64  4.06  0.86  0.97 -1.75  16.06  29.39
# 6   MTDT  1.50  2.52  2.34  4.69  4.84  0.84  0.41 -1.78  17.88  31.56
# 7   KOCE  1.47  2.41  1.52  6.76  4.30  0.85  0.91 -1.88  16.76  33.39
# 8    POG  1.46  2.58  1.76  5.58  4.76  0.88  0.70 -1.76  16.97  31.12
# 9     VR  1.40  2.44  1.88  6.18  4.55  1.09  0.36 -1.85  19.67  31.58
# 10  OVJG  1.32  2.68  2.27  4.52  4.09  0.91  0.36 -1.91  15.73  32.06
# 11  ZHAN  1.45  2.61  1.82  6.24  3.61  1.03  0.55 -1.97  20.52  31.45

# %%
teams = df['Team']
num_teams = len(teams)
score_data = []
row_total = []
for i in range(num_teams):
    team_a = teams[i]
    row = []
    wins = 0
    losses = 0
    draws = 0
    for j in range(num_teams):
        team_b = teams[j]
        if team_a == team_b:
            row.append(0)
        else:
            team_a_wins = sum(df.iloc[i, 1:10] > df.iloc[j, 1:10])
            team_b_wins = sum(df.iloc[i, 1:10] < df.iloc[j, 1:10])
            team_draw = sum(df.iloc[i, 1:10] == df.iloc[j, 1:10])
            score = f"{team_a_wins} - {team_b_wins} - {team_draw}"
            if team_a_wins > team_b_wins:
                row.append(f'<span style="color:green">{score}</span>')
                wins += 1
            elif team_b_wins > team_a_wins: 
                row.append(f'<span style="color:red">{score}</span>' )
                losses += 1
            else:
                row.append(score)
                draws +=1
                
    score_data.append(row)
    row_total.append(f"{wins} - {losses} - {draws}")

score_df = pd.DataFrame(score_data, columns=teams, index=teams)
score_df['Win Total'] = row_total


score_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_fbe2f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th id="T_fbe2f_level0_col0" class="col_heading level0 col0" >RAO</th>
#       <th id="T_fbe2f_level0_col1" class="col_heading level0 col1" >GRU</th>
#       <th id="T_fbe2f_level0_col2" class="col_heading level0 col2" >RIZZ</th>
#       <th id="T_fbe2f_level0_col3" class="col_heading level0 col3" >uwu</th>
#       <th id="T_fbe2f_level0_col4" class="col_heading level0 col4" >GOAt</th>
#       <th id="T_fbe2f_level0_col5" class="col_heading level0 col5" >BBB</th>
#       <th id="T_fbe2f_level0_col6" class="col_heading level0 col6" >MTDT</th>
#       <th id="T_fbe2f_level0_col7" class="col_heading level0 col7" >KOCE</th>
#       <th id="T_fbe2f_level0_col8" class="col_heading level0 col8" >POG</th>
#       <th id="T_fbe2f_level0_col9" class="col_heading level0 col9" >VR</th>
#       <th id="T_fbe2f_level0_col10" class="col_heading level0 col10" >OVJG</th>
#       <th id="T_fbe2f_level0_col11" class="col_heading level0 col11" >ZHAN</th>
#       <th id="T_fbe2f_level0_col12" class="col_heading level0 col12" >Win Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbe2f_level0_row0" class="row_heading level0 row0" >RAO</th>
#       <td id="T_fbe2f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_fbe2f_row0_col1" class="data row0 col1" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row0_col2" class="data row0 col2" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row0_col3" class="data row0 col3" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_fbe2f_row0_col4" class="data row0 col4" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row0_col5" class="data row0 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row0_col6" class="data row0 col6" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row0_col7" class="data row0 col7" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_fbe2f_row0_col8" class="data row0 col8" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_fbe2f_row0_col9" class="data row0 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row0_col10" class="data row0 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row0_col11" class="data row0 col11" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_fbe2f_row0_col12" class="data row0 col12" >3 - 8 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_fbe2f_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_fbe2f_row1_col0" class="data row1 col0" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_fbe2f_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_fbe2f_row1_col2" class="data row1 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_fbe2f_row1_col3" class="data row1 col3" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_fbe2f_row1_col4" class="data row1 col4" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row1_col5" class="data row1 col5" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_fbe2f_row1_col6" class="data row1 col6" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row1_col7" class="data row1 col7" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_fbe2f_row1_col8" class="data row1 col8" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_fbe2f_row1_col9" class="data row1 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row1_col10" class="data row1 col10" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row1_col11" class="data row1 col11" ><span style="color:red">2 - 7 - 0</span></td>
#       <td id="T_fbe2f_row1_col12" class="data row1 col12" >1 - 10 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_fbe2f_level0_row2" class="row_heading level0 row2" >RIZZ</th>
#       <td id="T_fbe2f_row2_col0" class="data row2 col0" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row2_col1" class="data row2 col1" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_fbe2f_row2_col3" class="data row2 col3" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_fbe2f_row2_col4" class="data row2 col4" ><span style="color:green">6 - 2 - 1</span></td>
#       <td id="T_fbe2f_row2_col5" class="data row2 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row2_col6" class="data row2 col6" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_fbe2f_row2_col7" class="data row2 col7" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row2_col8" class="data row2 col8" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row2_col9" class="data row2 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row2_col10" class="data row2 col10" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_fbe2f_row2_col11" class="data row2 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row2_col12" class="data row2 col12" >8 - 3 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_fbe2f_level0_row3" class="row_heading level0 row3" >uwu</th>
#       <td id="T_fbe2f_row3_col0" class="data row3 col0" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row3_col1" class="data row3 col1" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_fbe2f_row3_col2" class="data row3 col2" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_fbe2f_row3_col4" class="data row3 col4" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row3_col5" class="data row3 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row3_col6" class="data row3 col6" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row3_col7" class="data row3 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row3_col8" class="data row3 col8" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row3_col9" class="data row3 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row3_col10" class="data row3 col10" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_fbe2f_row3_col11" class="data row3 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_fbe2f_row3_col12" class="data row3 col12" >8 - 3 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_fbe2f_level0_row4" class="row_heading level0 row4" >GOAt</th>
#       <td id="T_fbe2f_row4_col0" class="data row4 col0" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row4_col1" class="data row4 col1" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_row4_col2" class="data row4 col2" ><span style="color:red">2 - 6 - 1</span></td>
#       <td id="T_fbe2f_row4_col3" class="data row4 col3" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_fbe2f_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_fbe2f_row4_col5" class="data row4 col5" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_fbe2f_ro

# %% [markdown]
# Average per game

# %%
teams = df['Team']
num_teams = len(teams)
score_data = []
row_total = []
for i in range(num_teams):
    team_a = teams[i]
    row = []
    wins = 0
    losses = 0
    draws = 0
    for j in range(num_teams):
        team_b = teams[j]
        if team_a == team_b:
            row.append(0)
        else:
            team_a_wins = sum(average_df.iloc[i, 1:10] > average_df.iloc[j, 1:10])
            team_b_wins = sum(average_df.iloc[i, 1:10] < average_df.iloc[j, 1:10])
            team_draw = sum(average_df.iloc[i, 1:10] == average_df.iloc[j, 1:10])
            score = f"{team_a_wins} - {team_b_wins} - {team_draw}"
            if team_a_wins > team_b_wins:
                row.append(f'<span style="color:green">{score}</span>')
                wins += 1
            elif team_b_wins > team_a_wins: 
                row.append(f'<span style="color:red">{score}</span>' )
                losses += 1
            else:
                row.append(score)
                draws +=1
                
    score_data.append(row)
    row_total.append(f"{wins} - {losses} - {draws}")

score_average_df = pd.DataFrame(score_data, columns=teams, index=teams)
score_average_df['Win Total'] = row_total


score_average_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b955a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th id="T_b955a_level0_col0" class="col_heading level0 col0" >RAO</th>
#       <th id="T_b955a_level0_col1" class="col_heading level0 col1" >GRU</th>
#       <th id="T_b955a_level0_col2" class="col_heading level0 col2" >RIZZ</th>
#       <th id="T_b955a_level0_col3" class="col_heading level0 col3" >uwu</th>
#       <th id="T_b955a_level0_col4" class="col_heading level0 col4" >GOAt</th>
#       <th id="T_b955a_level0_col5" class="col_heading level0 col5" >BBB</th>
#       <th id="T_b955a_level0_col6" class="col_heading level0 col6" >MTDT</th>
#       <th id="T_b955a_level0_col7" class="col_heading level0 col7" >KOCE</th>
#       <th id="T_b955a_level0_col8" class="col_heading level0 col8" >POG</th>
#       <th id="T_b955a_level0_col9" class="col_heading level0 col9" >VR</th>
#       <th id="T_b955a_level0_col10" class="col_heading level0 col10" >OVJG</th>
#       <th id="T_b955a_level0_col11" class="col_heading level0 col11" >ZHAN</th>
#       <th id="T_b955a_level0_col12" class="col_heading level0 col12" >Win Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b955a_level0_row0" class="row_heading level0 row0" >RAO</th>
#       <td id="T_b955a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b955a_row0_col1" class="data row0 col1" ><span style="color:green">8 - 1 - 0</span></td>
#       <td id="T_b955a_row0_col2" class="data row0 col2" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row0_col3" class="data row0 col3" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row0_col4" class="data row0 col4" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row0_col5" class="data row0 col5" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_b955a_row0_col6" class="data row0 col6" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_b955a_row0_col7" class="data row0 col7" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_b955a_row0_col8" class="data row0 col8" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_b955a_row0_col9" class="data row0 col9" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row0_col10" class="data row0 col10" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_b955a_row0_col11" class="data row0 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row0_col12" class="data row0 col12" >11 - 0 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_b955a_level0_row1" class="row_heading level0 row1" >GRU</th>
#       <td id="T_b955a_row1_col0" class="data row1 col0" ><span style="color:red">1 - 8 - 0</span></td>
#       <td id="T_b955a_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_b955a_row1_col2" class="data row1 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row1_col3" class="data row1 col3" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row1_col4" class="data row1 col4" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_b955a_row1_col5" class="data row1 col5" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row1_col6" class="data row1 col6" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row1_col7" class="data row1 col7" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row1_col8" class="data row1 col8" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row1_col9" class="data row1 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_b955a_row1_col10" class="data row1 col10" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row1_col11" class="data row1 col11" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_b955a_row1_col12" class="data row1 col12" >3 - 8 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_b955a_level0_row2" class="row_heading level0 row2" >RIZZ</th>
#       <td id="T_b955a_row2_col0" class="data row2 col0" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row2_col1" class="data row2 col1" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_b955a_row2_col3" class="data row2 col3" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row2_col4" class="data row2 col4" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row2_col5" class="data row2 col5" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row2_col6" class="data row2 col6" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row2_col7" class="data row2 col7" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row2_col8" class="data row2 col8" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row2_col9" class="data row2 col9" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row2_col10" class="data row2 col10" ><span style="color:green">8 - 1 - 0</span></td>
#       <td id="T_b955a_row2_col11" class="data row2 col11" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row2_col12" class="data row2 col12" >10 - 1 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_b955a_level0_row3" class="row_heading level0 row3" >uwu</th>
#       <td id="T_b955a_row3_col0" class="data row3 col0" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row3_col1" class="data row3 col1" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row3_col2" class="data row3 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b955a_row3_col4" class="data row3 col4" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row3_col5" class="data row3 col5" ><span style="color:green">7 - 2 - 0</span></td>
#       <td id="T_b955a_row3_col6" class="data row3 col6" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row3_col7" class="data row3 col7" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_b955a_row3_col8" class="data row3 col8" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row3_col9" class="data row3 col9" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_b955a_row3_col10" class="data row3 col10" ><span style="color:green">6 - 3 - 0</span></td>
#       <td id="T_b955a_row3_col11" class="data row3 col11" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row3_col12" class="data row3 col12" >7 - 4 - 0</td>
#     </tr>
#     <tr>
#       <th id="T_b955a_level0_row4" class="row_heading level0 row4" >GOAt</th>
#       <td id="T_b955a_row4_col0" class="data row4 col0" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row4_col1" class="data row4 col1" ><span style="color:green">5 - 4 - 0</span></td>
#       <td id="T_b955a_row4_col2" class="data row4 col2" ><span style="color:red">3 - 6 - 0</span></td>
#       <td id="T_b955a_row4_col3" class="data row4 col3" ><span style="color:red">4 - 5 - 0</span></td>
#       <td id="T_b955a_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_b955a_row4_col5" class="data row4 col5" ><span style="color:red">4 - 5 - 0</span></td>
